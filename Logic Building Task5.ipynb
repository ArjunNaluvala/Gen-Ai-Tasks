# %% [markdown]
# # Function-Based Problem Solving

# %% [markdown]
# Problem 1: Social Media – Post Engagement Analyzer

# %%
'''
Problem 1: Social Media – Post Engagement Analyzer
Problem Statement
Create a function to analyze engagement on a social media post.
Rules
Calculate total likes
If Total Likes ≥ 1000 → Viral Post
Otherwise → Normal Engagement
Real-Time Use
Social media analytics platforms
Marketing dashboards
Hint
Use function
Use loop for calculations
Expected Output Format
Total Likes: 1050
Post Status: Viral Post
'''

def analyze_post_engagement(likes_list):
    total_likes = 0

    # Calculate total likes
    for like in likes_list:
        total_likes += like

    # If Total Likes ≥ 1000 → Viral Post
    # Otherwise → Normal Engagement
    if total_likes >= 1000:
        status = "Viral Post"
    else:
        status = "Normal Engagement"

    # Print result
    print("Total Likes:", total_likes)
    print("Post Status:", status)

# List of likes
likes = []
n = int(input("Enter the number of likes: "))
for i in range(n):
    like = int(input(f"Enter the number of likes for post {i+1}: "))
    likes.append(like)
print()
analyze_post_engagement(likes)
# Out:
# Enter the number of likes:  6
# Enter the number of likes for post 1:  77
# Enter the number of likes for post 2:  150
# Enter the number of likes for post 3:  42
# Enter the number of likes for post 4:  63
# Enter the number of likes for post 5:  55
# Enter the number of likes for post 6:  44
# Total Likes: 431
# Post Status: Normal Engagement

# %% [markdown]
# Problem 2: Healthcare – Medicine Stock Alert System

# %%
'''
Problem 2: Healthcare – Medicine Stock Alert System
Problem Statement
Create a function to monitor medicine stock levels.
Rules
Stock < 10 → Low Stock Alert
Stock ≥ 10 → Stock Sufficient
Real-Time Use
Pharmacy management systems
Hospital inventory tracking
Hint
Use function
Use conditional logic
Expected Output Format
Medicine Stock: 6
Status: Low Stock Alert
'''

def check_medicine_stock(stock):

    # Stock < 10 → Low Stock Alert
    # Stock ≥ 10 → Stock Sufficient
    if stock < 10:
        status = "Low Stock Alert"
    else:
        status = "Stock Sufficient"

    # Print result
    print("Medicine Stock:", stock)
    print("Status:", status)

stock=int(input("Enter the medicine stock: "))
print()
check_medicine_stock(stock)
# Out:
# Enter the medicine stock:  4
# Medicine Stock: 4
# Status: Low Stock Alert

# %% [markdown]
# Problem 3: Agriculture – Rainfall Adequacy Checker

# %%
# Function: Rainfall Adequacy Checker
def rainfall_checker(rainfall_list, required_level):
    total_rainfall = 0
    status = ""
    # Calculate total rainfall
    for rain in rainfall_list:
        total_rainfall += rain
    # Calculate average rainfall
    average_rainfall = total_rainfall / len(rainfall_list)

    # Average ≥ required level → Adequate Rainfall
    # Otherwise → Inadequate Rainfall
    if average_rainfall >= required_level:
        status = "Adequate Rainfall"
    else:
        status = "Inadequate Rainfall"

    # Print result
    print("Average Rainfall:", round(average_rainfall))
    print("Rainfall Status:", status)


# List of seasonal rainfall per month
rainfall_list = []
n = int(input("Enter the number of months: "))
for i in range(n):
    rain = float(input(f"Enter the rainfall for month {i+1}: "))
    rainfall_list.append(rain)
print()
required_level = float(input("Enter the required rainfall level: "))
print()
rainfall_checker(rainfall_list, required_level)
# Out:
# Enter the number of months: 5
# Enter the rainfall for month 1: 70
# Enter the rainfall for month 2: 75
# Enter the rainfall for month 3: 68
# Enter the rainfall for month 4: 80
# Enter the rainfall for month 5: 67
#
# Enter the required rainfall level: 70
#
# Average Rainfall: 72
# Rainfall Status: Adequate Rainfall

# %% [markdown]
# Problem 4: Social Media – Duplicate Account Detection

# %%
def detect_duplicate_accounts(users):
    # Use set removes duplicates automatically
    unique_users = set(users)
    result = ""

    # If duplicates exist → Flag accounts
    # Else → Accounts are unique
    if len(users) != len(unique_users):
        result = "Yes"
    else:
        result = "No"
    print("Duplicate Accounts Found:", result)

# List of users
users = []
n = int(input("Enter the number of users: "))
for i in range(n):
    user = input(f"Enter the username for user {i+1}: ")
    users.append(user)
print()
detect_duplicate_accounts(users)
# Out:
# Enter the number of users: 5
# Enter the username for user 1: john123
# Enter the username for user 2: alex32
# Enter the username for user 3: ram65
# Enter the username for user 4: john123
# Enter the username for user 5: sita46
#
# Duplicate Accounts Found: Yes

# %% [markdown]
# Problem 5: Healthcare – Appointment Eligibility Checker

# %%
def check_appointment_eligibility(age):

    # Age ≥ 18 → Eligible
    # Age < 18 → Not Eligible
    if age >= 18:
        status = "Eligible"
    else:
        status = "Not Eligible"

    # Print result
    print("Patient Age:", age)
    print("Eligibility Status:", status)

age = int(input("Enter the patient age: "))
print()
check_appointment_eligibility(age)
# Out:
# Enter the patient age: 21
#
# Patient Age: 21
# Eligibility Status: Eligible

# %% [markdown]
# Problem 6: Agriculture – Premium Crop Price Filter

# %%
# Function to filter the Premium crop price
def filter_premium_crops(price_list):
    premium_crops = []

    # Price > ₹2000 → Premium Crop
    # Else → Regular Crop
    for price in price_list:
        if price > 2000:
            premium_crops.append(price)

    print("Premium Crops:", premium_crops)


# List of prices
crop_prices = []
n = int(input("Enter the number of crops: "))
for i in range(n):
    price = int(input(f"Enter the price for crop {i+1}: "))
    crop_prices.append(price)
print()
filter_premium_crops(crop_prices)
# Out:
# Enter the number of crops: 5
# Enter the price for crop 1: 1500
# Enter the price for crop 2: 2500
# Enter the price for crop 3: 1800
# Enter the price for crop 4: 3200
# Enter the price for crop 5: 1900
#
# Premium Crops: [2500, 3200]

# %% [markdown]
# Problem 7: System Monitoring – Application Health

# %%
# Function to check the health
def application_health_checker(error_count):

    # Errors = 0 → Healthy
    # Errors ≤ 5 → Minor Issues
    # Errors > 5 → Critical Issues
    if error_count == 0:
        status = "Healthy"
    elif error_count <= 5:
        status = "Minor Issues"
    else:
        status = "Critical Issues"

    # Print result
    print("Error Count:", error_count)
    print("System Status:", status)

error_count = int(input("Enter the number of errors: "))
print()
application_health_checker(error_count)
# Out:
# Enter the number of errors: 7
#
# Error Count: 7
# System Status: Critical Issues

# %% [markdown]
# Problem 8: Banking – Daily Transaction Limit Checker

# %%
def check_transaction_limit(amount):
    daily_limit = 50000

    # Amount within limit → Approved
    # Amount exceeds limit → Rejected
    if amount <= daily_limit:
        status = "Approved"
    else:
        status = "Rejected"

    # Print result
    print("Transaction Amount:", amount)
    print("Transaction Status:", status)

amount = int(input("Enter the transaction amount: "))
print()
check_transaction_limit(amount)
# Out:
# Enter the transaction amount: 60000
#
# Transaction Amount: 60000
# Transaction Status: Rejected

# %% [markdown]
# Problem 9: E-Learning – Student Attendance Eligibility

# %%
# Function to check the eligibility
def check_attendance_eligibility(attendance_list):
    total_days = len(attendance_list)
    present_days = 0

    # Attendance ≥ 75% → Eligible
    # Attendance < 75% → Not Eligible
    for day in attendance_list:
        if day == "P":
            present_days += 1

    # Calculate attendance percentage
    attendance_percentage = (present_days / total_days) * 100
    # Check eligibility
    if attendance_percentage >= 75:
        status = "Eligible"
    else:
        status = "Not Eligible"

    # Print result
    print("Attendance Percentage:", attendance_percentage)
    print("Exam Eligibility:", status)


# List of attendance
attendance_list = []
n = int(input("Enter the nuPmber of days: "))
for i in range(n):
    day = input(f"Enter the attendance for day {i+1}: ")
    attendance_list.append(day)
print()
check_attendance_eligibility(attendance_list)
# Out:
# Enter the nuPmber of days: 5
# Enter the attendance for day 1: P
# Enter the attendance for day 2: P
# Enter the attendance for day 3: A
# Enter the attendance for day 4: P
# Enter the attendance for day 5: P
#
# Attendance Percentage: 80.0
# Exam Eligibility: Eligible

# %% [markdown]
# Problem 10: Smart Electricity Bill Analyzer

# %%
# Function to analyze the electricity bill
def electricity_bill_analyzer(units):
    bill = 0

    # Billing calculation using slabs
    if units <= 100:
        bill = units * 3
    elif units <= 200:
        bill = (100 * 3) + ((units - 100) * 5)
    else:
        bill = (100 * 3) + (100 * 5) + ((units - 200) * 7)

    # Total bill < ₹500 → Low Usage
    # ₹500 – ₹1500 → Moderate Usage
    # ₹1500 → High Usage
    if bill < 500:
        status = "Low Usage"
    elif 500 <= bill <= 1500:
        status = "Moderate Usage"
    else:
        status = "High Usage"

    return bill, status

units_consumed = int(input("Enter the units consumed: "))
total_bill, usage_status = electricity_bill_analyzer(units_consumed)
print()

# Print result
print("Units Consumed:", units_consumed)
print("Total Bill: ₹", total_bill)
print("Usage Level:", usage_status)
# Out:
# Enter the units consumed: 250
#
# Units Consumed: 250
# Total Bill: ₹ 1150
# Usage Level: Moderate Usage
