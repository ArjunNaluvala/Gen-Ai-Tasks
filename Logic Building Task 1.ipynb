# %% [markdown]
# # 1. User Login Check
# ## Problem Statement:
# - Given a username and password, check whether login is successful.
# - username = "admin"
# - password = "1234"
# ## Requirements:
# - Print "Login Successful" if both username and password match
# - Otherwise print "Invalid Credentials"

# %%
username="admin"
password="1234"
user_inp=input("Enter the username : ")
if user_inp==username:
    pass_inp=input("Enter the password : ")
    if pass_inp==password:
        print("Login Successful")
    else:
        print("Wrong password")
else:
    print("Invalid Credentials")
# Out:
# Enter the username :  admin
# Enter the password :  1234
# Login Successful

# %% [markdown]
# # 2. Pass / Fail Analyzer
# ## Problem Statement:
# - Analyze student results.
# - marks = [45, 78, 90, 33, 60]
# ## Requirements:
# - A student passes if marks ≥ 50
# - Count the total number of pass students
# - Count the total number of fail students
# - Print the final result clearly

# %%
marks=[45,78,90,33,60]
pass_count=0
fail_count=0
for i in marks:
    if i>=50:
        pass_count=pass_count+1
    else:
        fail_count=fail_count+1
print(f"{pass_count} students are pass \n{fail_count} students are fail")
# Out:
# 3 students are pass
# 2 students are fail

# %% [markdown]
# # 3. Simple Data Cleaner
# ## Problem Statement:
# - Clean and standardize user names.
# - names = [" Alice ", "bob", " CHARLIE "]
#
# ### Requirements:
# - Remove extra spaces
# - Convert all names to lowercase
# - Print the cleaned list

# %%
names=[" Alice","bob"," CHARLIE"]
lst=[]
for i in names:
    i=i.strip().lower()
    lst.append(i)
print("The cleaned list is :",lst)
# Out:
# The cleaned list is : ['alice', 'bob', 'charlie']

# %% [markdown]
# # 4. Message Length Analyzer
# ## Problem Statement:
# - Analyze message sizes.
# - messages = ["Hi", "Welcome to the platform", "OK"]
#
# ## Requirements:
# - Print the length of each message
# - Flag messages longer than 10 characters

# %%
messages=["Hi","Welcome to the platform","OK"]
for i in messages:
    if len(i)>10:
        print(f"{i} length is {len(i)} and it is flaged")
    else:
        print(f"{i} length is {len(i)}")
# Out:
# Hi length is 2
# Welcome to the platform length is 23 and it is flaged
# OK length is 2

# %% [markdown]
# # 5. Error Message Detector
# ## Problem Statement:
# - Detect error messages from system logs.
# - logs = ["INFO", "ERROR", "WARNING", "ERROR"]
#
# ## Requirements:
# - Count the number of "ERROR" entries
# - Print the total error count

# %%
logs=["INFO","ERROR","WARNING","ERROR"]
error_count=0
for i in logs:
    i=i.lower()
    if i=="error":
        error_count+=1
print("Total error count is :",error_count)
# Out:
# Total error count is : 2
